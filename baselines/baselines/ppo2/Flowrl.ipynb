# %%
#!/usr/bin/env python3
import argparse
import multiprocessing
import os
import sys

import tensorflow as tf

import gym
# import 
from baselines import logger
from baselines.common import set_global_seeds
from baselines.common.cmd_util import make_multiple_mujoco_env
from baselines.common.vec_env.vec_normalize import ImVecNormalize
from baselines.flow_rl_utils.network import flow_dict
from baselines.ppo2 import ppo2
from baselines.ppo2.policies import MImVecPolicy, MImVecLstmPolicy, MImVecLnLstmPolicy

# %%
gym.envs.registry.env_specs
# Out:
# {'Acrobot-v1': EnvSpec(Acrobot-v1),
#  'AirRaid-ram-v0': EnvSpec(AirRaid-ram-v0),
#  'AirRaid-ram-v4': EnvSpec(AirRaid-ram-v4),
#  'AirRaid-ramDeterministic-v0': EnvSpec(AirRaid-ramDeterministic-v0),
#  'AirRaid-ramDeterministic-v4': EnvSpec(AirRaid-ramDeterministic-v4),
#  'AirRaid-ramNoFrameskip-v0': EnvSpec(AirRaid-ramNoFrameskip-v0),
#  'AirRaid-ramNoFrameskip-v4': EnvSpec(AirRaid-ramNoFrameskip-v4),
#  'AirRaid-v0': EnvSpec(AirRaid-v0),
#  'AirRaid-v4': EnvSpec(AirRaid-v4),
#  'AirRaidDeterministic-v0': EnvSpec(AirRaidDeterministic-v0),
#  'AirRaidDeterministic-v4': EnvSpec(AirRaidDeterministic-v4),
#  'AirRaidNoFrameskip-v0': EnvSpec(AirRaidNoFrameskip-v0),
#  'AirRaidNoFrameskip-v4': EnvSpec(AirRaidNoFrameskip-v4),
#  'Alien-ram-v0': EnvSpec(Alien-ram-v0),
#  'Alien-ram-v4': EnvSpec(Alien-ram-v4),
#  'Alien-ramDeterministic-v0': EnvSpec(Alien-ramDeterministic-v0),
#  'Alien-ramDeterministic-v4': EnvSpec(Alien-ramDeterministic-v4),
#  'Alien-ramNoFrameskip-v0': EnvSpec(Alien-ramNoFrameskip-v0),
#  'Alien-ramNoFrameskip-v4': EnvSpec(Alien-ramNoFrameskip-v4),
#  'Alien-v0': EnvSpec(Alien-v0),
#  'Alien-v4': EnvSpec(Alien-v4),
#  'AlienDeterministic-v0': EnvSpec(AlienDeterministic-v0),
#  'AlienDeterministic-v4': EnvSpec(AlienDeterministic-v4),
#  'AlienNoFrameskip-v0': EnvSpec(AlienNoFrameskip-v0),
#  'AlienNoFrameskip-v4': EnvSpec(AlienNoFrameskip-v4),
#  'Amidar-ram-v0': EnvSpec(Amidar-ram-v0),
#  'Amidar-ram-v4': EnvSpec(Amidar-ram-v4),
#  'Amidar-ramDeterministic-v0': EnvSpec(Amidar-ramDeterministic-v0),
#  'Amidar-ramDeterministic-v4': EnvSpec(Amidar-ramDeterministic-v4),
#  'Amidar-ramNoFrameskip-v0': EnvSpec(Amidar-ramNoFrameskip-v0),
#  'Amidar-ramNoFrameskip-v4': EnvSpec(Amidar-ramNoFrameskip-v4),
#  'Amidar-v0': EnvSpec(Amidar-v0),
#  'Amidar-v4': EnvSpec(Amidar-v4),
#  'AmidarDeterministic-v0': EnvSpec(AmidarDeterministic-v0),
#  'AmidarDeterministic-v4': EnvSpec(AmidarDeterministic-v4),
#  'AmidarNoFrameskip-v0': EnvSpec(AmidarNoFrameskip-v0),
#  'AmidarNoFrameskip-v4': EnvSpec(AmidarNoFrameskip-v4),
#  'Ant-v2': EnvSpec(Ant-v2),
#  'Assault-ram-v0': EnvSpec(Assault-ram-v0),
#  'Assault-ram-v4': EnvSpec(Assault-ram-v4),
#  'Assault-ramDeterministic-v0': EnvSpec(Assault-ramDeterministic-v0),
#  'Assault-ramDeterministic-v4': EnvSpec(Assault-ramDeterministic-v4),
#  'Assault-ramNoFrameskip-v0': EnvSpec(Assault-ramNoFrameskip-v0),
#  'Assault-ramNoFrameskip-v4': EnvSpec(Assault-ramNoFrameskip-v4),
#  'Assault-v0': EnvSpec(Assault-v0),
#  'Assault-v4': EnvSpec(Assault-v4),
#  'AssaultDeterministic-v0': EnvSpec(AssaultDeterministic-v0),
#  'AssaultDeterministic-v4': EnvSpec(AssaultDeterministic-v4),
#  'AssaultNoFrameskip-v0': EnvSpec(AssaultNoFrameskip-v0),
#  'AssaultNoFrameskip-v4': EnvSpec(AssaultNoFrameskip-v4),
#  'Asterix-ram-v0': EnvSpec(Asterix-ram-v0),
#  'Asterix-ram-v4': EnvSpec(Asterix-ram-v4),
#  'Asterix-ramDeterministic-v0': EnvSpec(Asterix-ramDeterministic-v0),
#  'Asterix-ramDeterministic-v4': EnvSpec(Asterix-ramDeterministic-v4),
#  'Asterix-ramNoFrameskip-v0': EnvSpec(Asterix-ramNoFrameskip-v0),
#  'Asterix-ramNoFrameskip-v4': EnvSpec(Asterix-ramNoFrameskip-v4),
#  'Asterix-v0': EnvSpec(Asterix-v0),
#  'Asterix-v4': EnvSpec(Asterix-v4),
#  'AsterixDeterministic-v0': EnvSpec(AsterixDeterministic-v0),
#  'AsterixDeterministic-v4': EnvSpec(AsterixDeterministic-v4),
#  'AsterixNoFrameskip-v0': EnvSpec(AsterixNoFrameskip-v0),
#  'AsterixNoFrameskip-v4': EnvSpec(AsterixNoFrameskip-v4),
#  'Asteroids-ram-v0': EnvSpec(Asteroids-ram-v0),
#  'Asteroids-ram-v4': EnvSpec(Asteroids-ram-v4),
#  'Asteroids-ramDeterministic-v0': EnvSpec(Asteroids-ramDeterministic-v0),
#  'Asteroids-ramDeterministic-v4': EnvSpec(Asteroids-ramDeterministic-v4),
#  'Asteroids-ramNoFrameskip-v0': EnvSpec(Asteroids-ramNoFrameskip-v0),
#  'Asteroids-ramNoFrameskip-v4': EnvSpec(Asteroids-ramNoFrameskip-v4),
#  'Asteroids-v0': EnvSpec(Asteroids-v0),
#  'Asteroids-v4': EnvSpec(Asteroids-v4),
#  'AsteroidsDeterministic-v0': EnvSpec(AsteroidsDeterministic-v0),
#  'AsteroidsDeterministic-v4': EnvSpec(AsteroidsDeterministic-v4),
#  'AsteroidsNoFrameskip-v0': EnvSpec(AsteroidsNoFrameskip-v0),
#  'AsteroidsNoFrameskip-v4': EnvSpec(AsteroidsNoFrameskip-v4),
#  'Atlantis-ram-v0': EnvSpec(Atlantis-ram-v0),
#  'Atlantis-ram-v4': EnvSpec(Atlantis-ram-v4),
#  'Atlantis-ramDeterministic-v0': EnvSpec(Atlantis-ramDeterministic-v0),
#  'Atlantis-ramDeterministic-v4': EnvSpec(Atlantis-ramDeterministic-v4),
#  'Atlantis-ramNoFrameskip-v0': EnvSpec(Atlantis-ramNoFrameskip-v0),
#  'Atlantis-ramNoFrameskip-v4': EnvSpec(Atlantis-ramNoFrameskip-v4),
#  'Atlantis-v0': EnvSpec(Atlantis-v0),
#  'Atlantis-v4': EnvSpec(Atlantis-v4),
#  'AtlantisDeterministic-v0': EnvSpec(AtlantisDeterministic-v0),
#  'AtlantisDeterministic-v4': EnvSpec(AtlantisDeterministic-v4),
#  'AtlantisNoFrameskip-v0': EnvSpec(AtlantisNoFrameskip-v0),
#  'AtlantisNoFrameskip-v4': EnvSpec(AtlantisNoFrameskip-v4),
#  'BankHeist-ram-v0': EnvSpec(BankHeist-ram-v0),
#  'BankHeist-ram-v4': EnvSpec(BankHeist-ram-v4),
#  'BankHeist-ramDeterministic-v0': EnvSpec(BankHeist-ramDeterministic-v0),
#  'BankHeist-ramDeterministic-v4': EnvSpec(BankHeist-ramDeterministic-v4),
#  'BankHeist-ramNoFrameskip-v0': EnvSpec(BankHeist-ramNoFrameskip-v0),
#  'BankHeist-ramNoFrameskip-v4': EnvSpec(BankHeist-ramNoFrameskip-v4),
#  'BankHeist-v0': EnvSpec(BankHeist-v0),
#  'BankHeist-v4': EnvSpec(BankHeist-v4),
#  'BankHeistDeterministic-v0': EnvSpec(BankHeistDeterministic-v0),
#  'BankHeistDeterministic-v4': EnvSpec(BankHeistDeterministic-v4),
#  'BankHeistNoFrameskip-v0': EnvSpec(BankHeistNoFrameskip-v0),
#  'BankHeistNoFrameskip-v4': EnvSpec(BankHeistNoFrameskip-v4),
#  'BattleZone-ram-v0': EnvSpec(BattleZone-ram-v0),
#  'BattleZone-ram-v4': EnvSpec(BattleZone-ram-v4),
#  'BattleZone-ramDeterministic-v0': EnvSpec(BattleZone-ramDeterministic-v0),
#  'BattleZone-ramDeterministic-v4': EnvSpec(BattleZone-ramDeterministic-v4),
#  'BattleZone-ramNoFrameskip-v0': EnvSpec(BattleZone-ramNoFrameskip-v0),
#  'BattleZone-ramNoFrameskip-v4': EnvSpec(BattleZone-ramNoFrameskip-v4),
#  'BattleZone-v0': EnvSpec(BattleZone-v0),
#  'BattleZone-v4': EnvSpec(BattleZone-v4),
#  'BattleZoneDeterministic-v0': EnvSpec(BattleZoneDeterministic-v0),
#  'BattleZoneDeterministic-v4': EnvSpec(BattleZoneDeterministic-v4),
#  'BattleZoneNoFrameskip-v0': EnvSpec(BattleZoneNoFrameskip-v0),
#  'BattleZoneNoFrameskip-v4': EnvSpec(BattleZoneNoFrameskip-v4),
#  'BeamRider-ram-v0': EnvSpec(BeamRider-ram-v0),
#  'BeamRider-ram-v4': EnvSpec(BeamRider-ram-v4),
#  'BeamRider-ramDeterministic-v0': EnvSpec(BeamRider-ramDeterministic-v0),
#  'BeamRider-ramDeterministic-v4': EnvSpec(BeamRider-ramDeterministic-v4),
#  'BeamRider-ramNoFrameskip-v0': EnvSpec(BeamRider-ramNoFrameskip-v0),
#  'BeamRider-ramNoFrameskip-v4': EnvSpec(BeamRider-ramNoFrameskip-v4),
#  'BeamRider-v0': EnvSpec(BeamRider-v0),
#  'BeamRider-v4': EnvSpec(BeamRider-v4),
#  'BeamRiderDeterministic-v0': EnvSpec(BeamRiderDeterministic-v0),
#  'BeamRiderDeterministic-v4': EnvSpec(BeamRiderDeterministic-v4),
#  'BeamRiderNoFrameskip-v0': EnvSpec(BeamRiderNoFrameskip-v0),
#  'BeamRiderNoFrameskip-v4': EnvSpec(BeamRiderNoFrameskip-v4),
#  'Berzerk-ram-v0': EnvSpec(Berzerk-ram-v0),
#  'Berzerk-ram-v4': EnvSpec(Berzerk-ram-v4),
#  'Berzerk-ramDeterministic-v0': EnvSpec(Berzerk-ramDeterministic-v0),
#  'Berzerk-ramDeterministic-v4': EnvSpec(Berzerk-ramDeterministic-v4),
#  'Berzerk-ramNoFrameskip-v0': EnvSpec(Berzerk-ramNoFrameskip-v0),
#  'Berzerk-ramNoFrameskip-v4': EnvSpec(Berzerk-ramNoFrameskip-v4),
#  'Berzerk-v0': EnvSpec(Berzerk-v0),
#  'Berzerk-v4': EnvSpec(Berzerk-v4),
#  'BerzerkDeterministic-v0': EnvSpec(BerzerkDeterministic-v0),
#  'BerzerkDeterministic-v4': EnvSpec(BerzerkDeterministic-v4),
#  'BerzerkNoFrameskip-v0': EnvSpec(BerzerkNoFrameskip-v0),
#  'BerzerkNoFrameskip-v4': EnvSpec(BerzerkNoFrameskip-v4),
#  'BipedalWalker-v2': EnvSpec(BipedalWalker-v2),
#  'BipedalWalkerHardcore-v2': EnvSpec(BipedalWalkerHardcore-v2),
#  'Blackjack-v0': EnvSpec(Blackjack-v0),
#  'Bowling-ram-v0': EnvSpec(Bowling-ram-v0),
#  'Bowling-ram-v4': EnvSpec(Bowling-ram-v4),
#  'Bowling-ramDeterministic-v0': EnvSpec(Bowling-ramDeterministic-v0),
#  'Bowling-ramDeterministic-v4': EnvSpec(Bowling-ramDeterministic-v4),
#  'Bowling-ramNoFrameskip-v0': EnvSpec(Bowling-ramNoFrameskip-v0),
#  'Bowling-ramNoFrameskip-v4': EnvSpec(Bowling-ramNoFrameskip-v4),
#  'Bowling-v0': EnvSpec(Bowling-v0),
#  'Bowling-v4': EnvSpec(Bowling-v4),
#  'BowlingDeterministic-v0': EnvSpec(BowlingDeterministic-v0),
#  'BowlingDeterministic-v4': EnvSpec(BowlingDeterministic-v4),
#  'BowlingNoFrameskip-v0': EnvSpec(BowlingNoFrameskip-v0),
#  'BowlingNoFrameskip-v4': EnvSpec(BowlingNoFrameskip-v4),
#  'Boxing-ram-v0': EnvSpec(Boxing-ram-v0),
#  'Boxing-ram-v4': EnvSpec(Boxing-ram-v4),
#  'Boxing-ramDeterministic-v0': EnvSpec(Boxing-ramDeterministic-v0),
#  'Boxing-ramDeterministic-v4': EnvSpec(Boxing-ramDeterministic-v4),
#  'Boxing-ramNoFrameskip-v0': EnvSpec(Boxing-ramNoFrameskip-v0),
#  'Boxing-ramNoFrameskip-v4': EnvSpec(Boxing-ramNoFrameskip-v4),
#  'Boxing-v0': EnvSpec(Boxing-v0),
#  'Boxing-v4': EnvSpec(Boxing-v4),
#  'BoxingDeterministic-v0': EnvSpec(BoxingDeterministic-v0),
#  'BoxingDeterministic-v4': EnvSpec(BoxingDeterministic-v4),
#  'BoxingNoFrameskip-v0': EnvSpec(BoxingNoFrameskip-v0),
#  'BoxingNoFrameskip-v4': EnvSpec(BoxingNoFrameskip-v4),
#  'Breakout-ram-v0': EnvSpec(Breakout-ram-v0),
#  'Breakout-ram-v4': EnvSpec(Breakout-ram-v4),
#  'Breakout-ramDeterministic-v0': EnvSpec(Breakout-ramDeterministic-v0),
#  'Breakout-ramDeterministic-v4': EnvSpec(Breakout-ramDeterministic-v4),
#  'Breakout-ramNoFrameskip-v0': EnvSpec(Breakout-ramNoFrameskip-v0),
#  'Breakout-ramNoFrameskip-v4': EnvSpec(Breakout-ramNoFrameskip-v4),
#  'Breakout-v0': EnvSpec(Breakout-v0),
#  'Breakout-v4': EnvSpec(Breakout-v4),
#  'BreakoutDeterministic-v0': EnvSpec(BreakoutDeterministic-v0),
#  'BreakoutDeterministic-v4': EnvSpec(BreakoutDeterministic-v4),
#  'BreakoutNoFrameskip-v0': EnvSpec(BreakoutNoFrameskip-v0),
#  'BreakoutNoFrameskip-v4': EnvSpec(BreakoutNoFrameskip-v4),
#  'CarRacing-v0': EnvSpec(CarRacing-v0),
#  'Carnival-ram-v0': EnvSpec(Carnival-ram-v0),
#  'Carnival-ram-v4': EnvSpec(Carnival-ram-v4),
#  'Carnival-ramDeterministic-v0': EnvSpec(Carnival-ramDeterministic-v0),
#  'Carnival-ramDeterministic-v4': EnvSpec(Carnival-ramDeterministic-v4),
#  'Carnival-ramNoFrameskip-v0': EnvSpec(Carnival-ramNoFrameskip-v0),
#  'Carnival-ramNoFrameskip-v4': EnvSpec(Carnival-ramNoFrameskip-v4),
#  'Carnival-v0': EnvSpec(Carnival-v0),
#  'Carnival-v4': EnvSpec(Carnival-v4),
#  'CarnivalDeterministic-v0': EnvSpec(CarnivalDeterministic-v0),
#  'CarnivalDeterministic-v4': EnvSpec(CarnivalDeterministic-v4),
#  'CarnivalNoFrameskip-v0': EnvSpec(CarnivalNoFrameskip-v0),
#  'CarnivalNoFrameskip-v4': EnvSpec(CarnivalNoFrameskip-v4),
#  'CartPole-v0': EnvSpec(CartPole-v0),
#  'CartPole-v1': EnvSpec(CartPole-v1),
#  'Centipede-ram-v0': EnvSpec(Centipede-ram-v0),
#  'Centipede-ram-v4': EnvSpec(Centipede-ram-v4),
#  'Centipede-ramDeterministic-v0': EnvSpec(Centipede-ramDeterministic-v0),
#  'Centipede-ramDeterministic-v4': EnvSpec(Centipede-ramDeterministic-v4),
#  'Centipede-ramNoFrameskip-v0': EnvSpec(Centipede-ramNoFrameskip-v0),
#  'Centipede-ramNoFrameskip-v4': EnvSpec(Centipede-ramNoFrameskip-v4),
#  'Centipede-v0': EnvSpec(Centipede-v0),
#  'Centipede-v4': EnvSpec(Centipede-v4),
#  'CentipedeDeterministic-v0': EnvSpec(CentipedeDeterministic-v0),
#  'CentipedeDeterministic-v4': EnvSpec(CentipedeDeterministic-v4),
#  'CentipedeNoFrameskip-v0': EnvSpec(CentipedeNoFrameskip-v0),
#  'CentipedeNoFrameskip-v4': EnvSpec(CentipedeNoFrameskip-v4),
#  'ChopperCommand-ram-v0': EnvSpec(ChopperCommand-ram-v0),
#  'ChopperCommand-ram-v4': EnvSpec(ChopperCommand-ram-v4),
#  'ChopperCommand-ramDeterministic-v0': EnvSpec(ChopperCommand-ramDeterministic-v0),
#  'ChopperCommand-ramDeterministic-v4': EnvSpec(ChopperCommand-ramDeterministic-v4),
#  'ChopperCommand-ramNoFrameskip-v0': EnvSpec(ChopperCommand-ramNoFrameskip-v0),
#  'ChopperCommand-ramNoFrameskip-v4': EnvSpec(ChopperCommand-ramNoFrameskip-v4),
#  'ChopperCommand-v0': EnvSpec(ChopperCommand-v0),
#  'ChopperCommand-v4': EnvSpec(ChopperCommand-v4),
#  'ChopperCommandDeterministic-v0': EnvSpec(ChopperCommandDeterministic-v0),
#  'ChopperCommandDeterministic-v4': EnvSpec(ChopperCommandDeterministic-v4),
#  'ChopperCommandNoFrameskip-v0': EnvSpec(ChopperCommandNoFrameskip-v0),
#  'ChopperCommandNoFrameskip-v4': EnvSpec(ChopperCommandNoFrameskip-v4),
#  'CliffWalking-v0': EnvSpec(CliffWalking-v0),
#  'Copy-v0': EnvSpec(Copy-v0),
#  'CrazyClimber-ram-v0': EnvSpec(CrazyClimber-ram-v0),
#  'CrazyClimber-ram-v4': EnvSpec(CrazyClimber-ram-v4),
#  'CrazyClimber-ramDeterministic-v0': EnvSpec(CrazyClimber-ramDeterministic-v0),
#  'CrazyClimber-ramDeterministic-v4': EnvSpec(CrazyClimber-ramDeterministic-v4),
#  'CrazyClimber-ramNoFrameskip-v0': EnvSpec(CrazyClimber-ramNoFrameskip-v0),
#  'CrazyClimber-ramNoFrameskip-v4': EnvSpec(CrazyClimber-ramNoFrameskip-v4),
#  'CrazyClimber-v0': EnvSpec(CrazyClimber-v0),
#  'CrazyClimber-v4': EnvSpec(CrazyClimber-v4),
#  'CrazyClimberDeterministic-v0': EnvSpec(CrazyClimberDeterministic-v0),
#  'CrazyClimberDeterministic-v4': EnvSpec(CrazyClimberDeterministic-v4),
#  'CrazyClimberNoFrameskip-v0': EnvSpec(CrazyClimberNoFrameskip-v0),
#  'CrazyClimberNoFrameskip-v4': EnvSpec(CrazyClimberNoFrameskip-v4),
#  'CubeCrash-v0': EnvSpec(CubeCrash-v0),
#  'CubeCrashScreenBecomesBlack-v0': EnvSpec(CubeCrashScreenBecomesBlack-v0),
#  'CubeCrashSparse-v0': EnvSpec(CubeCrashSparse-v0),
#  'DemonAttack-ram-v0': EnvSpec(DemonAttack-ram-v0),
#  'DemonAttack-ram-v4': EnvSpec(DemonAttack-ram-v4),
#  'DemonAttack-ramDeterministic-v0': EnvSpec(DemonAttack-ramDeterministic-v0),
#  'DemonAttack-ramDeterministic-v4': EnvSpec(DemonAttack-ramDeterministic-v4),
#  'DemonAttack-ramNoFrameskip-v0': EnvSpec(DemonAttack-ramNoFrameskip-v0),
#  'DemonAttack-ramNoFrameskip-v4': EnvSpec(DemonAttack-ramNoFrameskip-v4),
#  'DemonAttack-v0': EnvSpec(DemonAttack-v0),
#  'DemonAttack-v4': EnvSpec(DemonAttack-v4),
#  'DemonAttackDeterministic-v0': EnvSpec(DemonAttackDeterministic-v0),
#  'DemonAttackDeterministic-v4': EnvSpec(DemonAttackDeterministic-v4),
#  'DemonAttackNoFrameskip-v0': EnvSpec(DemonAttackNoFrameskip-v0),
#  'DemonAttackNoFrameskip-v4': EnvSpec(DemonAttackNoFrameskip-v4),
#  'DoubleDunk-ram-v0': EnvSpec(DoubleDunk-ram-v0),
#  'DoubleDunk-ram-v4': EnvSpec(DoubleDunk-ram-v4),
#  'DoubleDunk-ramDeterministic-v0': EnvSpec(DoubleDunk-ramDeterministic-v0),
#  'DoubleDunk-ramDeterministic-v4': EnvSpec(DoubleDunk-ramDeterministic-v4),
#  'DoubleDunk-ramNoFrameskip-v0': EnvSpec(DoubleDunk-ramNoFrameskip-v0),
#  'DoubleDunk-ramNoFrameskip-v4': EnvSpec(DoubleDunk-ramNoFrameskip-v4),
#  'DoubleDunk-v0': EnvSpec(DoubleDunk-v0),
#  'DoubleDunk-v4': EnvSpec(DoubleDunk-v4),
#  'DoubleDunkDeterministic-v0': EnvSpec(DoubleDunkDeterministic-v0),
#  'DoubleDunkDeterministic-v4': EnvSpec(DoubleDunkDeterministic-v4),
#  'DoubleDunkNoFrameskip-v0': EnvSpec(DoubleDunkNoFrameskip-v0),
#  'DoubleDunkNoFrameskip-v4': EnvSpec(DoubleDunkNoFrameskip-v4),
#  'DuplicatedInput-v0': EnvSpec(DuplicatedInput-v0),
#  'ElevatorAction-ram-v0': EnvSpec(ElevatorAction-ram-v0),
#  'ElevatorAction-ram-v4': EnvSpec(ElevatorAction-ram-v4),
#  'ElevatorAction-ramDeterministic-v0': EnvSpec(ElevatorAction-ramDeterministic-v0),
#  'ElevatorAction-ramDeterministic-v4': EnvSpec(ElevatorAction-ramDeterministic-v4),
#  'ElevatorAction-ramNoFrameskip-v0': EnvSpec(ElevatorAction-ramNoFrameskip-v0),
#  'ElevatorAction-ramNoFrameskip-v4': EnvSpec(ElevatorAction-ramNoFrameskip-v4),
#  'ElevatorAction-v0': EnvSpec(ElevatorAction-v0),
#  'ElevatorAction-v4': EnvSpec(ElevatorAction-v4),
#  'ElevatorActionDeterministic-v0': EnvSpec(ElevatorActionDeterministic-v0),
#  'ElevatorActionDeterministic-v4': EnvSpec(ElevatorActionDeterministic-v4),
#  'ElevatorActionNoFrameskip-v0': EnvSpec(ElevatorActionNoFrameskip-v0),
#  'ElevatorActionNoFrameskip-v4': EnvSpec(ElevatorActionNoFrameskip-v4),
#  'Enduro-ram-v0': EnvSpec(Enduro-ram-v0),
#  'Enduro-ram-v4': EnvSpec(Enduro-ram-v4),
#  'Enduro-ramDeterministic-v0': EnvSpec(Enduro-ramDeterministic-v0),
#  'Enduro-ramDeterministic-v4': EnvSpec(Enduro-ramDeterministic-v4),
#  'Enduro-ramNoFrameskip-v0': EnvSpec(Enduro-ramNoFrameskip-v0),
#  'Enduro-ramNoFrameskip-v4': EnvSpec(Enduro-ramNoFrameskip-v4),
#  'Enduro-v0': EnvSpec(Enduro-v0),
#  'Enduro-v4': EnvSpec(Enduro-v4),
#  'EnduroDeterministic-v0': EnvSpec(EnduroDeterministic-v0),
#  'EnduroDeterministic-v4': EnvSpec(EnduroDeterministic-v4),
#  'EnduroNoFrameskip-v0': EnvSpec(EnduroNoFrameskip-v0),
#  'EnduroNoFrameskip-v4': EnvSpec(EnduroNoFrameskip-v4),
#  'FetchPickAndPlace-v1': EnvSpec(FetchPickAndPlace-v1),
#  'FetchPickAndPlaceDense-v1': EnvSpec(FetchPickAndPlaceDense-v1),
#  'FetchPush-v1': EnvSpec(FetchPush-v1),
#  'FetchPushDense-v1': EnvSpec(FetchPushDense-v1),
#  'FetchReach-v1': EnvSpec(FetchReach-v1),
#  'FetchReachDense-v1': EnvSpec(FetchReachDense-v1),
#  'FetchSlide-v1': EnvSpec(FetchSlide-v1),
#  'FetchSlideDense-v1': EnvSpec(FetchSlideDense-v1),
#  'FishingDerby-ram-v0': EnvSpec(FishingDerby-ram-v0),
#  'FishingDerby-ram-v4': EnvSpec(FishingDerby-ram-v4),
#  'FishingDerby-ramDeterministic-v0': EnvSpec(FishingDerby-ramDeterministic-v0),
#  'FishingDerby-ramDeterministic-v4': EnvSpec(FishingDerby-ramDeterministic-v4),
#  'FishingDerby-ramNoFrameskip-v0': EnvSpec(FishingDerby-ramNoFrameskip-v0),
#  'FishingDerby-ramNoFrameskip-v4': EnvSpec(FishingDerby-ramNoFrameskip-v4),
#  'FishingDerby-v0': EnvSpec(FishingDerby-v0),
#  'FishingDerby-v4': EnvSpec(FishingDerby-v4),
#  'FishingDerbyDeterministic-v0': EnvSpec(FishingDerbyDeterministic-v0),
#  'FishingDerbyDeterministic-v4': EnvSpec(FishingDerbyDeterministic-v4),
#  'FishingDerbyNoFrameskip-v0': EnvSpec(FishingDerbyNoFrameskip-v0),
#  'FishingDerbyNoFrameskip-v4': EnvSpec(FishingDerbyNoFrameskip-v4),
#  'Freeway-ram-v0': EnvSpec(Freeway-ram-v0),
#  'Freeway-ram-v4': EnvSpec(Freeway-ram-v4),
#  'Freeway-ramDeterministic-v0': EnvSpec(Freeway-ramDeterministic-v0),
#  'Freeway-ramDeterministic-v4': EnvSpec(Freeway-ramDeterministic-v4),
#  'Freeway-ramNoFrameskip-v0': EnvSpec(Freeway-ramNoFrameskip-v0),
#  'Freeway-ramNoFrameskip-v4': EnvSpec(Freeway-ramNoFrameskip-v4),
#  'Freeway-v0': EnvSpec(Freeway-v0),
#  'Freeway-v4': EnvSpec(Freeway-v4),
#  'FreewayDeterministic-v0': EnvSpec(FreewayDeterministic-v0),
#  'FreewayDeterministic-v4': EnvSpec(FreewayDeterministic-v4),
#  'FreewayNoFrameskip-v0': EnvSpec(FreewayNoFrameskip-v0),
#  'FreewayNoFrameskip-v4': EnvSpec(FreewayNoFrameskip-v4),
#  'Frostbite-ram-v0': EnvSpec(Frostbite-ram-v0),
#  'Frostbite-ram-v4': EnvSpec(Frostbite-ram-v4),
#  'Frostbite-ramDeterministic-v0': EnvSpec(Frostbite-ramDeterministic-v0),
#  'Frostbite-ramDeterministic-v4': EnvSpec(Frostbite-ramDeterministic-v4),
#  'Frostbite-ramNoFrameskip-v0': EnvSpec(Frostbite-ramNoFrameskip-v0),
#  'Frostbite-ramNoFrameskip-v4': EnvSpec(Frostbite-ramNoFrameskip-v4),
#  'Frostbite-v0': EnvSpec(Frostbite-v0),
#  'Frostbite-v4': EnvSpec(Frostbite-v4),
#  'FrostbiteDeterministic-v0': EnvSpec(FrostbiteDeterministic-v0),
#  'FrostbiteDeterministic-v4': EnvSpec(FrostbiteDeterministic-v4),
#  'FrostbiteNoFrameskip-v0': EnvSpec(FrostbiteNoFrameskip-v0),
#  'FrostbiteNoFrameskip-v4': EnvSpec(FrostbiteNoFrameskip-v4),
#  'FrozenLake-v0': EnvSpec(FrozenLake-v0),
#  'FrozenLake8x8-v0': EnvSpec(FrozenLake8x8-v0),
#  'Gopher-ram-v0': EnvSpec(Gopher-ram-v0),
#  'Gopher-ram-v4': EnvSpec(Gopher-ram-v4),
#  'Gopher-ramDeterministic-v0': EnvSpec(Gopher-ramDeterministic-v0),
#  'Gopher-ramDeterministic-v4': EnvSpec(Gopher-ramDeterministic-v4),
#  'Gopher-ramNoFrameskip-v0': EnvSpec(Gopher-ramNoFrameskip-v0),
#  'Gopher-ramNoFrameskip-v4': EnvSpec(Gopher-ramNoFrameskip-v4),
#  'Gopher-v0': EnvSpec(Gopher-v0),
#  'Gopher-v4': EnvSpec(Gopher-v4),
#  'GopherDeterministic-v0': EnvSpec(GopherDeterministic-v0),
#  'GopherDeterministic-v4': EnvSpec(GopherDeterministic-v4),
#  'GopherNoFrameskip-v0': EnvSpec(GopherNoFrameskip-v0),
#  'GopherNoFrameskip-v4': EnvSpec(GopherNoFrameskip-v4),
#  'Gravitar-ram-v0': EnvSpec(Gravitar-ram-v0),
#  'Gravitar-ram-v4': EnvSpec(Gravitar-ram-v4),
#  'Gravitar-ramDeterministic-v0': EnvSpec(Gravitar-ramDeterministic-v0),
#  'Gravitar-ramDeterministic-v4': EnvSpec(Gravitar-ramDeterministic-v4),
#  'Gravitar-ramNoFrameskip-v0': EnvSpec(Gravitar-ramNoFrameskip-v0),
#  'Gravitar-ramNoFrameskip-v4': EnvSpec(Gravitar-ramNoFrameskip-v4),
#  'Gravitar-v0': EnvSpec(Gravitar-v0),
#  'Gravitar-v4': EnvSpec(Gravitar-v4),
#  'GravitarDeterministic-v0': EnvSpec(GravitarDeterministic-v0),
#  'GravitarDeterministic-v4': EnvSpec(GravitarDeterministic-v4),
#  'GravitarNoFrameskip-v0': EnvSpec(GravitarNoFrameskip-v0),
#  'GravitarNoFrameskip-v4': EnvSpec(GravitarNoFrameskip-v4),
#  'GuessingGame-v0': EnvSpec(GuessingGame-v0),
#  'HalfCheetah-v2': EnvSpec(HalfCheetah-v2),
#  'HandManipulateBlock-v0': EnvSpec(HandManipulateBlock-v0),
#  'HandManipulateBlockDense-v0': EnvSpec(HandManipulateBlockDense-v0),
#  'HandManipulateBlockFull-v0': EnvSpec(HandManipulateBlockFull-v0),
#  'HandManipulateBlockFullDense-v0': EnvSpec(HandManipulateBlockFullDense-v0),
#  'HandManipulateBlockRotateParallel-v0': EnvSpec(HandManipulateBlockRotateParallel-v0),
#  'HandManipulateBlockRotateParallelDense-v0': EnvSpec(HandManipulateBlockRotateParallelDense-v0),
#  'HandManipulateBlockRotateXYZ-v0': EnvSpec(HandManipulateBlockRotateXYZ-v0),
#  'HandManipulateBlockRotateXYZDense-v0': EnvSpec(HandManipulateBlockRotateXYZDense-v0),
#  'HandManipulateBlockRotateZ-v0': EnvSpec(HandManipulateBlockRotateZ-v0),
#  'HandManipulateBlockRotateZDense-v0': EnvSpec(HandManipulateBlockRotateZDense-v0),
#  'HandManipulateEgg-v0': EnvSpec(HandManipulateEgg-v0),
#  'HandManipulateEggDense-v0': EnvSpec(HandManipulateEggDense-v0),
#  'HandManipulateEggFull-v0': EnvSpec(HandManipulateEggFull-v0),
#  'HandManipulateEggFullDense-v0': EnvSpec(HandManipulateEggFullDense-v0),
#  'HandManipulateEggRotate-v0': EnvSpec(HandManipulateEggRotate-v0),
#  'HandManipulateEggRotateDense-v0': EnvSpec(HandManipulateEggRotateDense-v0),
#  'HandManipulatePen-v0': EnvSpec(HandManipulatePen-v0),
#  'HandManipulatePenDense-v0': EnvSpec(HandManipulatePenDense-v0),
#  'HandManipulatePenFull-v0': EnvSpec(HandManipulatePenFull-v0),
#  'HandManipulatePenFullDense-v0': EnvSpec(HandManipulatePenFullDense-v0),
#  'HandManipulatePenRotate-v0': EnvSpec(HandManipulatePenRotate-v0),
#  'HandManipulatePenRotateDense-v0': EnvSpec(HandManipulatePenRotateDense-v0),
#  'HandReach-v0': EnvSpec(HandReach-v0),
#  'HandReachDense-v0': EnvSpec(HandReachDense-v0),
#  'Hero-ram-v0': EnvSpec(Hero-ram-v0),
#  'Hero-ram-v4': EnvSpec(Hero-ram-v4),
#  'Hero-ramDeterministic-v0': EnvSpec(Hero-ramDeterministic-v0),
#  'Hero-ramDeterministic-v4': EnvSpec(Hero-ramDeterministic-v4),
#  'Hero-ramNoFrameskip-v0': EnvSpec(Hero-ramNoFrameskip-v0),
#  'Hero-ramNoFrameskip-v4': EnvSpec(Hero-ramNoFrameskip-v4),
#  'Hero-v0': EnvSpec(Hero-v0),
#  'Hero-v4': EnvSpec(Hero-v4),
#  'HeroDeterministic-v0': EnvSpec(HeroDeterministic-v0),
#  'HeroDeterministic-v4': EnvSpec(HeroDeterministic-v4),
#  'HeroNoFrameskip-v0': EnvSpec(HeroNoFrameskip-v0),
#  'HeroNoFrameskip-v4': EnvSpec(HeroNoFrameskip-v4),
#  'Hopper-v2': EnvSpec(Hopper-v2),
#  'HotterColder-v0': EnvSpec(HotterColder-v0),
#  'Humanoid-v2': EnvSpec(Humanoid-v2),
#  'HumanoidStandup-v2': EnvSpec(HumanoidStandup-v2),
#  'IceHockey-ram-v0': EnvSpec(IceHockey-ram-v0),
#  'IceHockey-ram-v4': EnvSpec(IceHockey-ram-v4),
#  'IceHockey-ramDeterministic-v0': EnvSpec(IceHockey-ramDeterministic-v0),
#  'IceHockey-ramDeterministic-v4': EnvSpec(IceHockey-ramDeterministic-v4),
#  'IceHockey-ramNoFrameskip-v0': EnvSpec(IceHockey-ramNoFrameskip-v0),
#  'IceHockey-ramNoFrameskip-v4': EnvSpec(IceHockey-ramNoFrameskip-v4),
#  'IceHockey-v0': EnvSpec(IceHockey-v0),
#  'IceHockey-v4': EnvSpec(IceHockey-v4),
#  'IceHockeyDeterministic-v0': EnvSpec(IceHockeyDeterministic-v0),
#  'IceHockeyDeterministic-v4': EnvSpec(IceHockeyDeterministic-v4),
#  'IceHockeyNoFrameskip-v0': EnvSpec(IceHockeyNoFrameskip-v0),
#  'IceHockeyNoFrameskip-v4': EnvSpec(IceHockeyNoFrameskip-v4),
#  'InvertedDoublePendulum-v2': EnvSpec(InvertedDoublePendulum-v2),
#  'InvertedPendulum-v2': EnvSpec(InvertedPendulum-v2),
#  'Jamesbond-ram-v0': EnvSpec(Jamesbond-ram-v0),
#  'Jamesbond-ram-v4': EnvSpec(Jamesbond-ram-v4),
#  'Jamesbond-ramDeterministic-v0': EnvSpec(Jamesbond-ramDeterministic-v0),
#  'Jamesbond-ramDeterministic-v4': EnvSpec(Jamesbond-ramDeterministic-v4),
#  'Jamesbond-ramNoFrameskip-v0': EnvSpec(Jamesbond-ramNoFrameskip-v0),
#  'Jamesbond-ramNoFrameskip-v4': EnvSpec(Jamesbond-ramNoFrameskip-v4),
#  'Jamesbond-v0': EnvSpec(Jamesbond-v0),
#  'Jamesbond-v4': EnvSpec(Jamesbond-v4),
#  'JamesbondDeterministic-v0': EnvSpec(JamesbondDeterministic-v0),
#  'JamesbondDeterministic-v4': EnvSpec(JamesbondDeterministic-v4),
#  'JamesbondNoFrameskip-v0': EnvSpec(JamesbondNoFrameskip-v0),
#  'JamesbondNoFrameskip-v4': EnvSpec(JamesbondNoFrameskip-v4),
#  'JourneyEscape-ram-v0': EnvSpec(JourneyEscape-ram-v0),
#  'JourneyEscape-ram-v4': EnvSpec(JourneyEscape-ram-v4),
#  'JourneyEscape-ramDeterministic-v0': EnvSpec(JourneyEscape-ramDeterministic-v0),
#  'JourneyEscape-ramDeterministic-v4': EnvSpec(JourneyEscape-ramDeterministic-v4),
#  'JourneyEscape-ramNoFrameskip-v0': EnvSpec(JourneyEscape-ramNoFrameskip-v0),
#  'JourneyEscape-ramNoFrameskip-v4': EnvSpec(JourneyEscape-ramNoFrameskip-v4),
#  'JourneyEscape-v0': EnvSpec(JourneyEscape-v0),
#  'JourneyEscape-v4': EnvSpec(JourneyEscape-v4),
#  'JourneyEscapeDeterministic-v0': EnvSpec(JourneyEscapeDeterministic-v0),
#  'JourneyEscapeDeterministic-v4': EnvSpec(JourneyEscapeDeterministic-v4),
#  'JourneyEscapeNoFrameskip-v0': EnvSpec(JourneyEscapeNoFrameskip-v0),
#  'JourneyEscapeNoFrameskip-v4': EnvSpec(JourneyEscapeNoFrameskip-v4),
#  'Kangaroo-ram-v0': EnvSpec(Kangaroo-ram-v0),
#  'Kangaroo-ram-v4': EnvSpec(Kangaroo-ram-v4),
#  'Kangaroo-ramDeterministic-v0': EnvSpec(Kangaroo-ramDeterministic-v0),
#  'Kangaroo-ramDeterministic-v4': EnvSpec(Kangaroo-ramDeterministic-v4),
#  'Kangaroo-ramNoFrameskip-v0': EnvSpec(Kangaroo-ramNoFrameskip-v0),
#  'Kangaroo-ramNoFrameskip-v4': EnvSpec(Kangaroo-ramNoFrameskip-v4),
#  'Kangaroo-v0': EnvSpec(Kangaroo-v0),
#  'Kangaroo-v4': EnvSpec(Kangaroo-v4),
#  'KangarooDeterministic-v0': EnvSpec(KangarooDeterministic-v0),
#  'KangarooDeterministic-v4': EnvSpec(KangarooDeterministic-v4),
#  'KangarooNoFrameskip-v0': EnvSpec(KangarooNoFrameskip-v0),
#  'KangarooNoFrameskip-v4': EnvSpec(KangarooNoFrameskip-v4),
#  'KellyCoinflip-v0': EnvSpec(KellyCoinflip-v0),
#  'KellyCoinflipGeneralized-v0': EnvSpec(KellyCoinflipGeneralized-v0),
#  'Krull-ram-v0': EnvSpec(Krull-ram-v0),
#  'Krull-ram-v4': EnvSpec(Krull-ram-v4),
#  'Krull-ramDeterministic-v0': EnvSpec(Krull-ramDeterministic-v0),
#  'Krull-ramDeterministic-v4': EnvSpec(Krull-ramDeterministic-v4),
#  'Krull-ramNoFrameskip-v0': EnvSpec(Krull-ramNoFrameskip-v0),
#  'Krull-ramNoFrameskip-v4': EnvSpec(Krull-ramNoFrameskip-v4),
#  'Krull-v0': EnvSpec(Krull-v0),
#  'Krull-v4': EnvSpec(Krull-v4),
#  'KrullDeterministic-v0': EnvSpec(KrullDeterministic-v0),
#  'KrullDeterministic-v4': EnvSpec(KrullDeterministic-v4),
#  'KrullNoFrameskip-v0': EnvSpec(KrullNoFrameskip-v0),
#  'KrullNoFrameskip-v4': EnvSpec(KrullNoFrameskip-v4),
#  'KungFuMaster-ram-v0': EnvSpec(KungFuMaster-ram-v0),
#  'KungFuMaster-ram-v4': EnvSpec(KungFuMaster-ram-v4),
#  'KungFuMaster-ramDeterministic-v0': EnvSpec(KungFuMaster-ramDeterministic-v0),
#  'KungFuMaster-ramDeterministic-v4': EnvSpec(KungFuMaster-ramDeterministic-v4),
#  'KungFuMaster-ramNoFrameskip-v0': EnvSpec(KungFuMaster-ramNoFrameskip-v0),
#  'KungFuMaster-ramNoFrameskip-v4': EnvSpec(KungFuMaster-ramNoFrameskip-v4),
#  'KungFuMaster-v0': EnvSpec(KungFuMaster-v0),
#  'KungFuMaster-v4': EnvSpec(KungFuMaster-v4),
#  'KungFuMasterDeterministic-v0': EnvSpec(KungFuMasterDeterministic-v0),
#  'KungFuMasterDeterministic-v4': EnvSpec(KungFuMasterDeterministic-v4),
#  'KungFuMasterNoFrameskip-v0': EnvSpec(KungFuMasterNoFrameskip-v0),
#  'KungFuMasterNoFrameskip-v4': EnvSpec(KungFuMasterNoFrameskip-v4),
#  'LunarLander-v2': EnvSpec(LunarLander-v2),
#  'LunarLanderContinuous-v2': EnvSpec(LunarLanderContinuous-v2),
#  'MemorizeDigits-v0': EnvSpec(MemorizeDigits-v0),
#  'MontezumaRevenge-ram-v0': EnvSpec(MontezumaRevenge-ram-v0),
#  'MontezumaRevenge-ram-v4': EnvSpec(MontezumaRevenge-ram-v4),
#  'MontezumaRevenge-ramDeterministic-v0': EnvSpec(MontezumaRevenge-ramDeterministic-v0),
#  'MontezumaRevenge-ramDeterministic-v4': EnvSpec(MontezumaRevenge-ramDeterministic-v4),
#  'MontezumaRevenge-ramNoFrameskip-v0': EnvSpec(MontezumaRevenge-ramNoFrameskip-v0),
#  'MontezumaRevenge-ramNoFrameskip-v4': EnvSpec(MontezumaRevenge-ramNoFrameskip-v4),
#  'MontezumaRevenge-v0': EnvSpec(MontezumaRevenge-v0),
#  'MontezumaRevenge-v4': EnvSpec(MontezumaRevenge-v4),
#  'MontezumaRevengeDeterministic-v0': EnvSpec(MontezumaRevengeDeterministic-v0),
#  'MontezumaRevengeDeterministic-v4': EnvSpec(MontezumaRevengeDeterministic-v4),
#  'MontezumaRevengeNoFrameskip-v0': EnvSpec(MontezumaRevengeNoFrameskip-v0),
#  'MontezumaRevengeNoFrameskip-v4': EnvSpec(MontezumaRevengeNoFrameskip-v4),
#  'MountainCar-v0': EnvSpec(MountainCar-v0),
#  'MountainCarContinuous-v0': EnvSpec(MountainCarContinuous-v0),
#  'MsPacman-ram-v0': EnvSpec(MsPacman-ram-v0),
#  'MsPacman-ram-v4': EnvSpec(MsPacman-ram-v4),
#  'MsPacman-ramDeterministic-v0': EnvSpec(MsPacman-ramDeterministic-v0),
#  'MsPacman-ramDeterministic-v4': EnvSpec(MsPacman-ramDeterministic-v4),
#  'MsPacman-ramNoFrameskip-v0': EnvSpec(MsPacman-ramNoFrameskip-v0),
#  'MsPacman-ramNoFrameskip-v4': EnvSpec(MsPacman-ramNoFrameskip-v4),
#  'MsPacman-v0': EnvSpec(MsPacman-v0),
#  'MsPacman-v4': EnvSpec(MsPacman-v4),
#  'MsPacmanDeterministic-v0': EnvSpec(MsPacmanDeterministic-v0),
#  'MsPacmanDeterministic-v4': EnvSpec(MsPacmanDeterministic-v4),
#  'MsPacmanNoFrameskip-v0': EnvSpec(MsPacmanNoFrameskip-v0),
#  'MsPacmanNoFrameskip-v4': EnvSpec(MsPacmanNoFrameskip-v4),
#  'NChain-v0': EnvSpec(NChain-v0),
#  'NameThisGame-ram-v0': EnvSpec(NameThisGame-ram-v0),
#  'NameThisGame-ram-v4': EnvSpec(NameThisGame-ram-v4),
#  'NameThisGame-ramDeterministic-v0': EnvSpec(NameThisGame-ramDeterministic-v0),
#  'NameThisGame-ramDeterministic-v4': EnvSpec(NameThisGame-ramDeterministic-v4),
#  'NameThisGame-ramNoFrameskip-v0': EnvSpec(NameThisGame-ramNoFrameskip-v0),
#  'NameThisGame-ramNoFrameskip-v4': EnvSpec(NameThisGame-ramNoFrameskip-v4),
#  'NameThisGame-v0': EnvSpec(NameThisGame-v0),
#  'NameThisGame-v4': EnvSpec(NameThisGame-v4),
#  'NameThisGameDeterministic-v0': EnvSpec(NameThisGameDeterministic-v0),
#  'NameThisGameDeterministic-v4': EnvSpec(NameThisGameDeterministic-v4),
#  'NameThisGameNoFrameskip-v0': EnvSpec(NameThisGameNoFrameskip-v0),
#  'NameThisGameNoFrameskip-v4': EnvSpec(NameThisGameNoFrameskip-v4),
#  'Pendulum-v0': EnvSpec(Pendulum-v0),
#  'Phoenix-ram-v0': EnvSpec(Phoenix-ram-v0),
#  'Phoenix-ram-v4': EnvSpec(Phoenix-ram-v4),
#  'Phoenix-ramDeterministic-v0': EnvSpec(Phoenix-ramDeterministic-v0),
#  'Phoenix-ramDeterministic-v4': EnvSpec(Phoenix-ramDeterministic-v4),
#  'Phoenix-ramNoFrameskip-v0': EnvSpec(Phoenix-ramNoFrameskip-v0),
#  'Phoenix-ramNoFrameskip-v4': EnvSpec(Phoenix-ramNoFrameskip-v4),
#  'Phoenix-v0': EnvSpec(Phoenix-v0),
#  'Phoenix-v4': EnvSpec(Phoenix-v4),
#  'PhoenixDeterministic-v0': EnvSpec(PhoenixDeterministic-v0),
#  'PhoenixDeterministic-v4': EnvSpec(PhoenixDeterministic-v4),
#  'PhoenixNoFrameskip-v0': EnvSpec(PhoenixNoFrameskip-v0),
#  'PhoenixNoFrameskip-v4': EnvSpec(PhoenixNoFrameskip-v4),
#  'Pitfall-ram-v0': EnvSpec(Pitfall-ram-v0),
#  'Pitfall-ram-v4': EnvSpec(Pitfall-ram-v4),
#  'Pitfall-ramDeterministic-v0': EnvSpec(Pitfall-ramDeterministic-v0),
#  'Pitfall-ramDeterministic-v4': EnvSpec(Pitfall-ramDeterministic-v4),
#  'Pitfall-ramNoFrameskip-v0': EnvSpec(Pitfall-ramNoFrameskip-v0),
#  'Pitfall-ramNoFrameskip-v4': EnvSpec(Pitfall-ramNoFrameskip-v4),
#  'Pitfall-v0': EnvSpec(Pitfall-v0),
#  'Pitfall-v4': EnvSpec(Pitfall-v4),
#  'PitfallDeterministic-v0': EnvSpec(PitfallDeterministic-v0),
#  'PitfallDeterministic-v4': EnvSpec(PitfallDeterministic-v4),
#  'PitfallNoFrameskip-v0': EnvSpec(PitfallNoFrameskip-v0),
#  'PitfallNoFrameskip-v4': EnvSpec(PitfallNoFrameskip-v4),
#  'Pong-ram-v0': EnvSpec(Pong-ram-v0),
#  'Pong-ram-v4': EnvSpec(Pong-ram-v4),
#  'Pong-ramDeterministic-v0': EnvSpec(Pong-ramDeterministic-v0),
#  'Pong-ramDeterministic-v4': EnvSpec(Pong-ramDeterministic-v4),
#  'Pong-ramNoFrameskip-v0': EnvSpec(Pong-ramNoFrameskip-v0),
#  'Pong-ramNoFrameskip-v4': EnvSpec(Pong-ramNoFrameskip-v4),
#  'Pong-v0': EnvSpec(Pong-v0),
#  'Pong-v4': EnvSpec(Pong-v4),
#  'PongDeterministic-v0': EnvSpec(PongDeterministic-v0),
#  'PongDeterministic-v4': EnvSpec(PongDeterministic-v4),
#  'PongNoFrameskip-v0': EnvSpec(PongNoFrameskip-v0),
#  'PongNoFrameskip-v4': EnvSpec(PongNoFrameskip-v4),
#  'Pooyan-ram-v0': EnvSpec(Pooyan-ram-v0),
#  'Pooyan-ram-v4': EnvSpec(Pooyan-ram-v4),
#  'Pooyan-ramDeterministic-v0': EnvSpec(Pooyan-ramDeterministic-v0),
#  'Pooyan-ramDeterministic-v4': EnvSpec(Pooyan-ramDeterministic-v4),
#  'Pooyan-ramNoFrameskip-v0': EnvSpec(Pooyan-ramNoFrameskip-v0),
#  'Pooyan-ramNoFrameskip-v4': EnvSpec(Pooyan-ramNoFrameskip-v4),
#  'Pooyan-v0': EnvSpec(Pooyan-v0),
#  'Pooyan-v4': EnvSpec(Pooyan-v4),
#  'PooyanDeterministic-v0': EnvSpec(PooyanDeterministic-v0),
#  'PooyanDeterministic-v4': EnvSpec(PooyanDeterministic-v4),
#  'PooyanNoFrameskip-v0': EnvSpec(PooyanNoFrameskip-v0),
#  'PooyanNoFrameskip-v4': EnvSpec(PooyanNoFrameskip-v4),
#  'PrivateEye-ram-v0': EnvSpec(PrivateEye-ram-v0),
#  'PrivateEye-ram-v4': EnvSpec(PrivateEye-ram-v4),
#  'PrivateEye-ramDeterministic-v0': EnvSpec(PrivateEye-ramDeterministic-v0),
#  'PrivateEye-ramDeterministic-v4': EnvSpec(PrivateEye-ramDeterministic-v4),
#  'PrivateEye-ramNoFrameskip-v0': EnvSpec(PrivateEye-ramNoFrameskip-v0),
#  'PrivateEye-ramNoFrameskip-v4': EnvSpec(PrivateEye-ramNoFrameskip-v4),
#  'PrivateEye-v0': EnvSpec(PrivateEye-v0),
#  'PrivateEye-v4': EnvSpec(PrivateEye-v4),
#  'PrivateEyeDeterministic-v0': EnvSpec(PrivateEyeDeterministic-v0),
#  'PrivateEyeDeterministic-v4': EnvSpec(PrivateEyeDeterministic-v4),
#  'PrivateEyeNoFrameskip-v0': EnvSpec(PrivateEyeNoFrameskip-v0),
#  'PrivateEyeNoFrameskip-v4': EnvSpec(PrivateEyeNoFrameskip-v4),
#  'Pusher-v2': EnvSpec(Pusher-v2),
#  'Qbert-ram-v0': EnvSpec(Qbert-ram-v0),
#  'Qbert-ram-v4': EnvSpec(Qbert-ram-v4),
#  'Qbert-ramDeterministic-v0': EnvSpec(Qbert-ramDeterministic-v0),
#  'Qbert-ramDeterministic-v4': EnvSpec(Qbert-ramDeterministic-v4),
#  'Qbert-ramNoFrameskip-v0': EnvSpec(Qbert-ramNoFrameskip-v0),
#  'Qbert-ramNoFrameskip-v4': EnvSpec(Qbert-ramNoFrameskip-v4),
#  'Qbert-v0': EnvSpec(Qbert-v0),
#  'Qbert-v4': EnvSpec(Qbert-v4),
#  'QbertDeterministic-v0': EnvSpec(QbertDeterministic-v0),
#  'QbertDeterministic-v4': EnvSpec(QbertDeterministic-v4),
#  'QbertNoFrameskip-v0': EnvSpec(QbertNoFrameskip-v0),
#  'QbertNoFrameskip-v4': EnvSpec(QbertNoFrameskip-v4),
#  'Reacher-v2': EnvSpec(Reacher-v2),
#  'RepeatCopy-v0': EnvSpec(RepeatCopy-v0),
#  'Reverse-v0': EnvSpec(Reverse-v0),
#  'ReversedAddition-v0': EnvSpec(ReversedAddition-v0),
#  'ReversedAddition3-v0': EnvSpec(ReversedAddition3-v0),
#  'Riverraid-ram-v0': EnvSpec(Riverraid-ram-v0),
#  'Riverraid-ram-v4': EnvSpec(Riverraid-ram-v4),
#  'Riverraid-ramDeterministic-v0': EnvSpec(Riverraid-ramDeterministic-v0),
#  'Riverraid-ramDeterministic-v4': EnvSpec(Riverraid-ramDeterministic-v4),
#  'Riverraid-ramNoFrameskip-v0': EnvSpec(Riverraid-ramNoFrameskip-v0),
#  'Riverraid-ramNoFrameskip-v4': EnvSpec(Riverraid-ramNoFrameskip-v4),
#  'Riverraid-v0': EnvSpec(Riverraid-v0),
#  'Riverraid-v4': EnvSpec(Riverraid-v4),
#  'RiverraidDeterministic-v0': EnvSpec(RiverraidDeterministic-v0),
#  'RiverraidDeterministic-v4': EnvSpec(RiverraidDeterministic-v4),
#  'RiverraidNoFrameskip-v0': EnvSpec(RiverraidNoFrameskip-v0),
#  'RiverraidNoFrameskip-v4': EnvSpec(RiverraidNoFrameskip-v4),
#  'RoadRunner-ram-v0': EnvSpec(RoadRunner-ram-v0),
#  'RoadRunner-ram-v4': EnvSpec(RoadRunner-ram-v4),
#  'RoadRunner-ramDeterministic-v0': EnvSpec(RoadRunner-ramDeterministic-v0),
#  'RoadRunner-ramDeterministic-v4': EnvSpec(RoadRunner-ramDeterministic-v4),
#  'RoadRunner-ramNoFrameskip-v0': EnvSpec(RoadRunner-ramNoFrameskip-v0),
#  'RoadRunner-ramNoFrameskip-v4': EnvSpec(RoadRunner-ramNoFrameskip-v4),
#  'RoadRunner-v0': EnvSpec(RoadRunner-v0),
#  'RoadRunner-v4': EnvSpec(RoadRunner-v4),
#  'RoadRunnerDeterministic-v0': EnvSpec(RoadRunnerDeterministic-v0),
#  'RoadRunnerDeterministic-v4': EnvSpec(RoadRunnerDeterministic-v4),
#  'RoadRunnerNoFrameskip-v0': EnvSpec(RoadRunnerNoFrameskip-v0),
#  'RoadRunnerNoFrameskip-v4': EnvSpec(RoadRunnerNoFrameskip-v4),
#  'Robotank-ram-v0': EnvSpec(Robotank-ram-v0),
#  'Robotank-ram-v4': EnvSpec(Robotank-ram-v4),
#  'Robotank-ramDeterministic-v0': EnvSpec(Robotank-ramDeterministic-v0),
#  'Robotank-ramDeterministic-v4': EnvSpec(Robotank-ramDeterministic-v4),
#  'Robotank-ramNoFrameskip-v0': EnvSpec(Robotank-ramNoFrameskip-v0),
#  'Robotank-ramNoFrameskip-v4': EnvSpec(Robotank-ramNoFrameskip-v4),
#  'Robotank-v0': EnvSpec(Robotank-v0),
#  'Robotank-v4': EnvSpec(Robotank-v4),
#  'RobotankDeterministic-v0': EnvSpec(RobotankDeterministic-v0),
#  'RobotankDeterministic-v4': EnvSpec(RobotankDeterministic-v4),
#  'RobotankNoFrameskip-v0': EnvSpec(RobotankNoFrameskip-v0),
#  'RobotankNoFrameskip-v4': EnvSpec(RobotankNoFrameskip-v4),
#  'Roulette-v0': EnvSpec(Roulette-v0),
#  'Seaquest-ram-v0': EnvSpec(Seaquest-ram-v0),
#  'Seaquest-ram-v4': EnvSpec(Seaquest-ram-v4),
#  'Seaquest-ramDeterministic-v0': EnvSpec(Seaquest-ramDeterministic-v0),
#  'Seaquest-ramDeterministic-v4': EnvSpec(Seaquest-ramDeterministic-v4),
#  'Seaquest-ramNoFrameskip-v0': EnvSpec(Seaquest-ramNoFrameskip-v0),
#  'Seaquest-ramNoFrameskip-v4': EnvSpec(Seaquest-ramNoFrameskip-v4),
#  'Seaquest-v0': EnvSpec(Seaquest-v0),
#  'Seaquest-v4': EnvSpec(Seaquest-v4),
#  'SeaquestDeterministic-v0': EnvSpec(SeaquestDeterministic-v0),
#  'SeaquestDeterministic-v4': EnvSpec(SeaquestDeterministic-v4),
#  'SeaquestNoFrameskip-v0': EnvSpec(SeaquestNoFrameskip-v0),
#  'SeaquestNoFrameskip-v4': EnvSpec(SeaquestNoFrameskip-v4),
#  'Skiing-ram-v0': EnvSpec(Skiing-ram-v0),
#  'Skiing-ram-v4': EnvSpec(Skiing-ram-v4),
#  'Skiing-ramDeterministic-v0': EnvSpec(Skiing-ramDeterministic-v0),
#  'Skiing-ramDeterministic-v4': EnvSpec(Skiing-ramDeterministic-v4),
#  'Skiing-ramNoFrameskip-v0': EnvSpec(Skiing-ramNoFrameskip-v0),
#  'Skiing-ramNoFrameskip-v4': EnvSpec(Skiing-ramNoFrameskip-v4),
#  'Skiing-v0': EnvSpec(Skiing-v0),
#  'Skiing-v4': EnvSpec(Skiing-v4),
#  'SkiingDeterministic-v0': EnvSpec(SkiingDeterministic-v0),
#  'SkiingDeterministic-v4': EnvSpec(SkiingDeterministic-v4),
#  'SkiingNoFrameskip-v0': EnvSpec(SkiingNoFrameskip-v0),
#  'SkiingNoFrameskip-v4': EnvSpec(SkiingNoFrameskip-v4),
#  'Solaris-ram-v0': EnvSpec(Solaris-ram-v0),
#  'Solaris-ram-v4': EnvSpec(Solaris-ram-v4),
#  'Solaris-ramDeterministic-v0': EnvSpec(Solaris-ramDeterministic-v0),
#  'Solaris-ramDeterministic-v4': EnvSpec(Solaris-ramDeterministic-v4),
#  'Solaris-ramNoFrameskip-v0': EnvSpec(Solaris-ramNoFrameskip-v0),
#  'Solaris-ramNoFrameskip-v4': EnvSpec(Solaris-ramNoFrameskip-v4),
#  'Solaris-v0': EnvSpec(Solaris-v0),
#  'Solaris-v4': EnvSpec(Solaris-v4),
#  'SolarisDeterministic-v0': EnvSpec(SolarisDeterministic-v0),
#  'SolarisDeterministic-v4': EnvSpec(SolarisDeterministic-v4),
#  'SolarisNoFrameskip-v0': EnvSpec(SolarisNoFrameskip-v0),
#  'SolarisNoFrameskip-v4': EnvSpec(SolarisNoFrameskip-v4),
#  'SpaceInvaders-ram-v0': EnvSpec(SpaceInvaders-ram-v0),
#  'SpaceInvaders-ram-v4': EnvSpec(SpaceInvaders-ram-v4),
#  'SpaceInvaders-ramDeterministic-v0': EnvSpec(SpaceInvaders-ramDeterministic-v0),
#  'SpaceInvaders-ramDeterministic-v4': EnvSpec(SpaceInvaders-ramDeterministic-v4),
#  'SpaceInvaders-ramNoFrameskip-v0': EnvSpec(SpaceInvaders-ramNoFrameskip-v0),
#  'SpaceInvaders-ramNoFrameskip-v4': EnvSpec(SpaceInvaders-ramNoFrameskip-v4),
#  'SpaceInvaders-v0': EnvSpec(SpaceInvaders-v0),
#  'SpaceInvaders-v4': EnvSpec(SpaceInvaders-v4),
#  'SpaceInvadersDeterministic-v0': EnvSpec(SpaceInvadersDeterministic-v0),
#  'SpaceInvadersDeterministic-v4': EnvSpec(SpaceInvadersDeterministic-v4),
#  'SpaceInvadersNoFrameskip-v0': EnvSpec(SpaceInvadersNoFrameskip-v0),
#  'SpaceInvadersNoFrameskip-v4': EnvSpec(SpaceInvadersNoFrameskip-v4),
#  'StarGunner-ram-v0': EnvSpec(StarGunner-ram-v0),
#  'StarGunner-ram-v4': EnvSpec(StarGunner-ram-v4),
#  'StarGunner-ramDeterministic-v0': EnvSpec(StarGunner-ramDeterministic-v0),
#  'StarGunner-ramDeterministic-v4': EnvSpec(StarGunner-ramDeterministic-v4),
#  'StarGunner-ramNoFrameskip-v0': EnvSpec(StarGunner-ramNoFrameskip-v0),
#  'StarGunner-ramNoFrameskip-v4': EnvSpec(StarGunner-ramNoFrameskip-v4),
#  'StarGunner-v0': EnvSpec(StarGunner-v0),
#  'StarGunner-v4': EnvSpec(StarGunner-v4),
#  'StarGunnerDeterministic-v0': EnvSpec(StarGunnerDeterministic-v0),
#  'StarGunnerDeterministic-v4': EnvSpec(StarGunnerDeterministic-v4),
#  'StarGunnerNoFrameskip-v0': EnvSpec(StarGunnerNoFrameskip-v0),
#  'StarGunnerNoFrameskip-v4': EnvSpec(StarGunnerNoFrameskip-v4),
#  'Striker-v2': EnvSpec(Striker-v2),
#  'Swimmer-v2': EnvSpec(Swimmer-v2),
#  'Taxi-v2': EnvSpec(Taxi-v2),
#  'Tennis-ram-v0': EnvSpec(Tennis-ram-v0),
#  'Tennis-ram-v4': EnvSpec(Tennis-ram-v4),
#  'Tennis-ramDeterministic-v0': EnvSpec(Tennis-ramDeterministic-v0),
#  'Tennis-ramDeterministic-v4': EnvSpec(Tennis-ramDeterministic-v4),
#  'Tennis-ramNoFrameskip-v0': EnvSpec(Tennis-ramNoFrameskip-v0),
#  'Tennis-ramNoFrameskip-v4': EnvSpec(Tennis-ramNoFrameskip-v4),
#  'Tennis-v0': EnvSpec(Tennis-v0),
#  'Tennis-v4': EnvSpec(Tennis-v4),
#  'TennisDeterministic-v0': EnvSpec(TennisDeterministic-v0),
#  'TennisDeterministic-v4': EnvSpec(TennisDeterministic-v4),
#  'TennisNoFrameskip-v0': EnvSpec(TennisNoFrameskip-v0),
#  'TennisNoFrameskip-v4': EnvSpec(TennisNoFrameskip-v4),
#  'Thrower-v2': EnvSpec(Thrower-v2),
#  'TimePilot-ram-v0': EnvSpec(TimePilot-ram-v0),
#  'TimePilot-ram-v4': EnvSpec(TimePilot-ram-v4),
#  'TimePilot-ramDeterministic-v0': EnvSpec(TimePilot-ramDeterministic-v0),
#  'TimePilot-ramDeterministic-v4': EnvSpec(TimePilot-ramDeterministic-v4),
#  'TimePilot-ramNoFrameskip-v0': EnvSpec(TimePilot-ramNoFrameskip-v0),
#  'TimePilot-ramNoFrameskip-v4': EnvSpec(TimePilot-ramNoFrameskip-v4),
#  'TimePilot-v0': EnvSpec(TimePilot-v0),
#  'TimePilot-v4': EnvSpec(TimePilot-v4),
#  'TimePilotDeterministic-v0': EnvSpec(TimePilotDeterministic-v0),
#  'TimePilotDeterministic-v4': EnvSpec(TimePilotDeterministic-v4),
#  'TimePilotNoFrameskip-v0': EnvSpec(TimePilotNoFrameskip-v0),
#  'TimePilotNoFrameskip-v4': EnvSpec(TimePilotNoFrameskip-v4),
#  'Tutankham-ram-v0': EnvSpec(Tutankham-ram-v0),
#  'Tutankham-ram-v4': EnvSpec(Tutankham-ram-v4),
#  'Tutankham-ramDeterministic-v0': EnvSpec(Tutankham-ramDeterministic-v0),
#  'Tutankham-ramDeterministic-v4': EnvSpec(Tutankham-ramDeterministic-v4),
#  'Tutankham-ramNoFrameskip-v0': EnvSpec(Tutankham-ramNoFrameskip-v0),
#  'Tutankham-ramNoFrameskip-v4': EnvSpec(Tutankham-ramNoFrameskip-v4),
#  'Tutankham-v0': EnvSpec(Tutankham-v0),
#  'Tutankham-v4': EnvSpec(Tutankham-v4),
#  'TutankhamDeterministic-v0': EnvSpec(TutankhamDeterministic-v0),
#  'TutankhamDeterministic-v4': EnvSpec(TutankhamDeterministic-v4),
#  'TutankhamNoFrameskip-v0': EnvSpec(TutankhamNoFrameskip-v0),
#  'TutankhamNoFrameskip-v4': EnvSpec(TutankhamNoFrameskip-v4),
#  'UpNDown-ram-v0': EnvSpec(UpNDown-ram-v0),
#  'UpNDown-ram-v4': EnvSpec(UpNDown-ram-v4),
#  'UpNDown-ramDeterministic-v0': EnvSpec(UpNDown-ramDeterministic-v0),
#  'UpNDown-ramDeterministic-v4': EnvSpec(UpNDown-ramDeterministic-v4),
#  'UpNDown-ramNoFrameskip-v0': EnvSpec(UpNDown-ramNoFrameskip-v0),
#  'UpNDown-ramNoFrameskip-v4': EnvSpec(UpNDown-ramNoFrameskip-v4),
#  'UpNDown-v0': EnvSpec(UpNDown-v0),
#  'UpNDown-v4': EnvSpec(UpNDown-v4),
#  'UpNDownDeterministic-v0': EnvSpec(UpNDownDeterministic-v0),
#  'UpNDownDeterministic-v4': EnvSpec(UpNDownDeterministic-v4),
#  'UpNDownNoFrameskip-v0': EnvSpec(UpNDownNoFrameskip-v0),
#  'UpNDownNoFrameskip-v4': EnvSpec(UpNDownNoFrameskip-v4),
#  'Venture-ram-v0': EnvSpec(Venture-ram-v0),
#  'Venture-ram-v4': EnvSpec(Venture-ram-v4),
#  'Venture-ramDeterministic-v0': EnvSpec(Venture-ramDeterministic-v0),
#  'Venture-ramDeterministic-v4': EnvSpec(Venture-ramDeterministic-v4),
#  'Venture-ramNoFrameskip-v0': EnvSpec(Venture-ramNoFrameskip-v0),
#  'Venture-ramNoFrameskip-v4': EnvSpec(Venture-ramNoFrameskip-v4),
#  'Venture-v0': EnvSpec(Venture-v0),
#  'Venture-v4': EnvSpec(Venture-v4),
#  'VentureDeterministic-v0': EnvSpec(VentureDeterministic-v0),
#  'VentureDeterministic-v4': EnvSpec(VentureDeterministic-v4),
#  'VentureNoFrameskip-v0': EnvSpec(VentureNoFrameskip-v0),
#  'VentureNoFrameskip-v4': EnvSpec(VentureNoFrameskip-v4),
#  'VideoPinball-ram-v0': EnvSpec(VideoPinball-ram-v0),
#  'VideoPinball-ram-v4': EnvSpec(VideoPinball-ram-v4),
#  'VideoPinball-ramDeterministic-v0': EnvSpec(VideoPinball-ramDeterministic-v0),
#  'VideoPinball-ramDeterministic-v4': EnvSpec(VideoPinball-ramDeterministic-v4),
#  'VideoPinball-ramNoFrameskip-v0': EnvSpec(VideoPinball-ramNoFrameskip-v0),
#  'VideoPinball-ramNoFrameskip-v4': EnvSpec(VideoPinball-ramNoFrameskip-v4),
#  'VideoPinball-v0': EnvSpec(VideoPinball-v0),
#  'VideoPinball-v4': EnvSpec(VideoPinball-v4),
#  'VideoPinballDeterministic-v0': EnvSpec(VideoPinballDeterministic-v0),
#  'VideoPinballDeterministic-v4': EnvSpec(VideoPinballDeterministic-v4),
#  'VideoPinballNoFrameskip-v0': EnvSpec(VideoPinballNoFrameskip-v0),
#  'VideoPinballNoFrameskip-v4': EnvSpec(VideoPinballNoFrameskip-v4),
#  'Walker2d-v2': EnvSpec(Walker2d-v2),
#  'WizardOfWor-ram-v0': EnvSpec(WizardOfWor-ram-v0),
#  'WizardOfWor-ram-v4': EnvSpec(WizardOfWor-ram-v4),
#  'WizardOfWor-ramDeterministic-v0': EnvSpec(WizardOfWor-ramDeterministic-v0),
#  'WizardOfWor-ramDeterministic-v4': EnvSpec(WizardOfWor-ramDeterministic-v4),
#  'WizardOfWor-ramNoFrameskip-v0': EnvSpec(WizardOfWor-ramNoFrameskip-v0),
#  'WizardOfWor-ramNoFrameskip-v4': EnvSpec(WizardOfWor-ramNoFrameskip-v4),
#  'WizardOfWor-v0': EnvSpec(WizardOfWor-v0),
#  'WizardOfWor-v4': EnvSpec(WizardOfWor-v4),
#  'WizardOfWorDeterministic-v0': EnvSpec(WizardOfWorDeterministic-v0),
#  'WizardOfWorDeterministic-v4': EnvSpec(WizardOfWorDeterministic-v4),
#  'WizardOfWorNoFrameskip-v0': EnvSpec(WizardOfWorNoFrameskip-v0),
#  'WizardOfWorNoFrameskip-v4': EnvSpec(WizardOfWorNoFrameskip-v4),
#  'YarsRevenge-ram-v0': EnvSpec(YarsRevenge-ram-v0),
#  'YarsRevenge-ram-v4': EnvSpec(YarsRevenge-ram-v4),
#  'YarsRevenge-ramDeterministic-v0': EnvSpec(YarsRevenge-ramDeterministic-v0),
#  'YarsRevenge-ramDeterministic-v4': EnvSpec(YarsRevenge-ramDeterministic-v4),
#  'YarsRevenge-ramNoFrameskip-v0': EnvSpec(YarsRevenge-ramNoFrameskip-v0),
#  'YarsRevenge-ramNoFrameskip-v4': EnvSpec(YarsRevenge-ramNoFrameskip-v4),
#  'YarsRevenge-v0': EnvSpec(YarsRevenge-v0),
#  'YarsRevenge-v4': EnvSpec(YarsRevenge-v4),
#  'YarsRevengeDeterministic-v0': EnvSpec(YarsRevengeDeterministic-v0),
#  'YarsRevengeDeterministic-v4': EnvSpec(YarsRevengeDeterministic-v4),
#  'YarsRevengeNoFrameskip-v0': EnvSpec(YarsRevengeNoFrameskip-v0),
#  'YarsRevengeNoFrameskip-v4': EnvSpec(YarsRevengeNoFrameskip-v4),
#  'Zaxxon-ram-v0': EnvSpec(Zaxxon-ram-v0),
#  'Zaxxon-ram-v4': EnvSpec(Zaxxon-ram-v4),
#  'Zaxxon-ramDeterministic-v0': EnvSpec(Zaxxon-ramDeterministic-v0),
#  'Zaxxon-ramDeterministic-v4': EnvSpec(Zaxxon-ramDeterministic-v4),
#  'Zaxxon-ramNoFrameskip-v0': EnvSpec(Zaxxon-ramNoFrameskip-v0),
#  'Zaxxon-ramNoFrameskip-v4': EnvSpec(Zaxxon-ramNoFrameskip-v4),
#  'Zaxxon-v0': EnvSpec(Zaxxon-v0),
#  'Zaxxon-v4': EnvSpec(Zaxxon-v4),
#  'ZaxxonDeterministic-v0': EnvSpec(ZaxxonDeterministic-v0),
#  'ZaxxonDeterministic-v4': EnvSpec(ZaxxonDeterministic-v4),
#  'ZaxxonNoFrameskip-v0': EnvSpec(ZaxxonNoFrameskip-v0),
#  'ZaxxonNoFrameskip-v4': EnvSpec(ZaxxonNoFrameskip-v4)}

# %%
def str2bool(v):
    return v.lower() in ("yes", "true", "t", "1")


class EnvParameterChanger():
    def get_gym_env_parameter(self, parser):
        tmp_args, _ = parser.parse_known_args()
        self.env = tmp_args.env_id
        print(self.env)
        assert self.env in gym.envs.registry.env_specs
        self.env_args_dict = gym.envs.registry.env_specs[self.env]._kwargs
        for key, value in self.env_args_dict.items():
            if key not in tmp_args:
                parser.add_argument('--' + key,
                                    type=type(value) if type(value) != bool else str2bool,
                                    default=value)
        return parser

    def set_gym_env_parameter(self, args):
        args_dict = vars(args)
        for key in self.env_args_dict:
            gym.envs.registry.env_specs[self.env]._kwargs[key] = args_dict[key]


def train(args):
    logger.configure(args.main_path)

    if args.diff_frames:
        assert "stack_frames" in args

    seed = int.from_bytes(os.urandom(4), byteorder='big')
    set_global_seeds(seed)
    env = ImVecNormalize(make_multiple_mujoco_env(
        args.env_id, args.number_of_agents, seed))

    ncpu = multiprocessing.cpu_count()
    if sys.platform == 'darwin': ncpu //= 2
    ncpu = 1
    config = tf.ConfigProto(allow_soft_placement=True,
                            intra_op_parallelism_threads=ncpu,
                            inter_op_parallelism_threads=ncpu)
    config.gpu_options.allow_growth = True
    tf.Session(config=config).__enter__()
    with tf.device("/device:GPU:0"):
        if args.policy == "cnn":
            policy = MImVecPolicy
        elif args.policy == "lstm_cnn":
            policy = MImVecLstmPolicy
        elif args.policy == "lnlstm_cnn":
            policy = MImVecLnLstmPolicy
        else:
            raise ValueError

    ppo2.learn(
        policy=policy,
        env=env,
        nsteps=args.nsteps,
        nminibatches=args.nminibatches,
        lam=args.lam,
        gamma=args.gamma,
        noptepochs=args.noptepochs,
        log_interval=1,
        ent_coef=0.0,
        lr=args.learning_rate,
        cliprange=args.cliprange,
        total_timesteps=int(args.num_timesteps * 1.01),
        add_flownet=args.add_flownet,
        flownet_path=args.flownet_path,
        flow_key=args.flow_key,
        train_from_scratch=args.train_from_scratch,
        large_cnn=args.large_cnn,
        add_predicted_flow_to_vec=args.add_predicted_flow_to_vec,
        diff_frames=args.diff_frames)

# %%
import easydict

# %%
def main(args=None):
    if args is None:
        parser = argparse.ArgumentParser()
        parser.add_argument('--main_path', type=str, default='../../../LOG_DIR/')
        parser.add_argument('--env_id', type=str, default="Catcher3d-v1")
        parser.add_argument('--nsteps', type=int, default=128)
        parser.add_argument('--nminibatches', type=int, default=4)
        parser.add_argument('--lam', type=float, default=0.95)
        parser.add_argument('--gamma', type=float, default=0.99)
        parser.add_argument('--noptepochs', type=int, default=2)
        parser.add_argument('--learning_rate', type=float, default=1e-4)
        parser.add_argument('--cliprange', type=float, default=0.2)
        parser.add_argument('--num_timesteps', type=int, default=int(2e7))
        parser.add_argument('--number_of_agents', type=int, default=8)
        parser.add_argument('--add_flownet', type=str2bool, default=True)
        parser.add_argument('--flownet_path', type=str, default="../../../networks/Catcher3d/")
        parser.add_argument('--flow_key', type=str, default='normal', choices=flow_dict)
        parser.add_argument('--policy', type=str, choices=("cnn", "lstm_cnn", "lnlstm_cnn"),
                            default="cnn")
        parser.add_argument('--train_from_scratch', type=str2bool, default=False)
        parser.add_argument('--large_cnn', type=str2bool, default=False)
        parser.add_argument('--add_predicted_flow_to_vec', type=str2bool, default=False)
        parser.add_argument('--diff_frames', type=str2bool, default=False)

        changer = EnvParameterChanger()
        parser = changer.get_gym_env_parameter(parser)

        args = parser.parse_args()
        changer.set_gym_env_parameter(args)

    train(args)

# %%
if __name__ == '__main__':
    main()
# Out:
# Catcher3d-v1
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-c7bc734e5e35> in <module>
#       1 if __name__ == '__main__':
# ----> 2     main()
#
# <ipython-input-4-1415ee542eef> in main(args)
#      24
#      25         changer = EnvParameterChanger()
# ---> 26         parser = changer.get_gym_env_parameter(parser)
#      27
#      28         args = parser.parse_args()
#
# <ipython-input-2-69f9eb8c1fa9> in get_gym_env_parameter(self, parser)
#       8         self.env = tmp_args.env_id
#       9         print(self.env)
# ---> 10         assert self.env in gym.envs.registry.env_specs
#      11         self.env_args_dict = gym.envs.registry.env_specs[self.env]._kwargs
#      12         for key, value in self.env_args_dict.items():
#
# AssertionError:

# %%
# %tb
# Out:
# ---------------------------------------------------------
# SystemExit              Traceback (most recent call last)
# <ipython-input-8-c7bc734e5e35> in <module>
#       1 if __name__ == '__main__':
# ----> 2     main()
#
# <ipython-input-7-762fbfbddee9> in main(args)
#      27         parser = changer.get_gym_env_parameter(parser)
#      28
# ---> 29         args = parser.parse_args()
#      30         changer.set_gym_env_parameter(args)
#      31
#
# /usr/lib/python3.5/argparse.py in parse_args(self, args, namespace)
#    1736         if argv:
#    1737             msg = _('unrecognized arguments: %s')
# -> 1738             self.error(msg % ' '.join(argv))
#    1739         return args
#    1740
#
# /usr/lib/python3.5/argparse.py in error(self, message)
#    2392         self.print_usage(_sys.stderr)
#    2393         args = {'prog': self.prog, 'message': message}
# -> 2394         self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#
# /usr/lib/python3.5/argparse.py in exit(self, status, message)
#    2379         if message:
#    2380             self._print_message(message, _sys.stderr)
# -> 2381         _sys.exit(status)
#    2382
#    2383     def error(self, message):
#
# SystemExit: 2
